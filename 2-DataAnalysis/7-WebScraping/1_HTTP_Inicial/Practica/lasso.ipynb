# %% [markdown]
# # Ejercicio Scraping
#
# Descargar letras de canciones
#
# Utilizando beautiful soup descargar todas las canciones de [Lasso](https://es.wikipedia.org/wiki/Lasso_(cantante)) que hay en [letras.com](https://www.letras.com/lasso/)

# %%
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd

letras_url = "https://www.letras.com/lasso"

url_obtenido = requests.get(letras_url)
soup = BeautifulSoup(url_obtenido.text, "html.parser")

def descargar_letras(artista):
    # COMPLETAR
    return
        
artista = "lasso"
descargar_letras(artista)

# %%
url_obtenido = requests.get(letras_url)
soup = BeautifulSoup(url_obtenido.text, "html.parser")

# %%
songs_container = soup.find_all('li', class_='songList-table-row --song isVisible')

# %%
songs_list = []

for song in songs_container:
    songs_list.append((song['data-name'][0], song['data-name']))
#    print(song['data-name'])

# %%
songs_list
# Out:
# [('A', 'Algo Mas'),
#  ('A', 'Algodón'),
#  ('B', 'Bilingües (part. Mau y Ricky)'),
#  ('C', 'Cerebro'),
#  ('C', 'Cero'),
#  ('C', 'Clavos'),
#  ('C', 'Cómo Te Odio'),
#  ('C', 'Corriendo Con Tijeras'),
#  ('c', 'ctrl-z'),
#  ('D', 'De mí, de mí, de mí (part. José Madero)'),
#  ('D', 'De Tú a Tú'),
#  ('D', 'Diferente'),
#  ('D', 'DIOS'),
#  ('E', 'Elefantes En La Barriga'),
#  ('E', 'En Otra Vida (part. Yami Safdie y Carin Leon)'),
#  ('E', 'En Otra Vida (part. Yami Safdie)'),
#  ('E', 'Escalas Eternas'),
#  ('E', 'Ese Final Ya Me Lo Sé'),
#  ('E', 'Eva'),
#  ('F', 'Feliz Por Ti'),
#  ('F', 'Final Feliz'),
#  ('G', 'Gracias'),
#  ('H', 'Hasta Ese Día'),
#  ('H', 'Huyendo'),
#  ('I', 'Ibuprofeno'),
#  ('K', 'Kamikaze'),
#  ('L', 'La Lotería'),
#  ('L', 'Ladrones (part. Danna Paola)'),
#  ('L', 'Los Amigos No Se Besan En La Boca (part. Ana Guerra)'),
#  ('L', 'Los Hombres Son Todos Iguales'),
#  ('M', 'Mala Memoria'),
#  ('M', 'Me Arruinaste Netflix (part. Micro TDH)'),
#  ('M', 'Mi Canción Favorita (part. Susana Cala)'),
#  ('M', 'Mi Imaginación'),
#  ('M', 'Mientras Mentias'),
#  ('M', 'Mmm'),
#  ('N', 'No Escuches Esta Canción (part. Micro TDH)'),
#  ('N', 'No Me Trates de Olvidar'),
#  ('N', 'No Pares De Bailar'),
#  ('O', 'Odio Que No Te Odio (part. Cami)'),
#  ('O', 'Ojala'),
#  ('O', 'Ojos Marrones'),
#  ('O', 'Ojos Marrones (part. Sebastian Yatra)'),
#  ('O', 'Oma'),
#  ('.', '... pero no me dejes'),
#  ('P', 'Perdón Pero No Te Perdono'),
#  ('P', 'Plástico'),
#  ('Q', 'QUEBRANTO (part. Leo Rizzi)'),
#  ('Q', 'Quédate Con Él'),
#  ('Q', 'Quiero Que Me Quieras'),
#  ('Q', 'Quiero Que Vuelvas'),
#  ('R', 'Rompecabezas'),
#  ('S', 'Siempre Llegas Tarde (part. Sofia Reyes)'),
#  ('S', 'Sin Mover Un Dedo'),
#  ('S', 'Sin Otro Sentido'),
#  ('S', 'Souvenir'),
#  ('S', 'Subtítulos (part. Danna Paola)'),
#  ('T', 'Te Veo'),
#  ('T', 'Tenemos Que Hablar'),
#  ('T', 'Tiempo Fallo'),
#  ('T', 'Tiempo Pasará (La Historia De Saria)'),
#  ('T', 'Todo Regresa'),
#  ('U', 'Un Millón Como Tú (part. Cami)'),
#  ('¿', '¿vienes o voy?'),
#  ('V', 'Vamos a Mi Ritmo (part. Isabela Souza)'),
#  ('Y', 'Yo-yo')]

# %%
df = pd.DataFrame(songs_list, columns=['Inicial','Titulo'])

# %%
df.sort_values(by='Inicial')
# Out:
#    Inicial                                  Titulo
# 44       .                    ... pero no me dejes
# 0        A                                Algo Mas
# 1        A                                 Algodón
# 2        B           Bilingües (part. Mau y Ricky)
# 3        C                                 Cerebro
# ..     ...                                     ...
# 62       U          Un Millón Como Tú (part. Cami)
# 64       V  Vamos a Mi Ritmo (part. Isabela Souza)
# 65       Y                                   Yo-yo
# 8        c                                  ctrl-z
# 63       ¿                          ¿vienes o voy?
#
# [66 rows x 2 columns]

# %%
df['Autor'] = 'Lasso'

# %%
df
# Out:
#    Inicial                                  Titulo  Autor
# 0        A                                Algo Mas  Lasso
# 1        A                                 Algodón  Lasso
# 2        B           Bilingües (part. Mau y Ricky)  Lasso
# 3        C                                 Cerebro  Lasso
# 4        C                                    Cero  Lasso
# ..     ...                                     ...    ...
# 61       T                            Todo Regresa  Lasso
# 62       U          Un Millón Como Tú (part. Cami)  Lasso
# 63       ¿                          ¿vienes o voy?  Lasso
# 64       V  Vamos a Mi Ritmo (part. Isabela Souza)  Lasso
# 65       Y                                   Yo-yo  Lasso
#
# [66 rows x 3 columns]
