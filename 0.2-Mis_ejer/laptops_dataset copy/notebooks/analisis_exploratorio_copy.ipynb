# %%
import os
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Configuración de la ruta del sistema a la carpeta desde donde se importan las funciones

# %%
root_path = Path(os.getcwd()).resolve().parent
sys.path.append(str(root_path))

# %%
from scripts.auto_importer_laptops import CompleteDescribeTable

# %% [markdown]
# ## Leer archivo ``csv`` limpio después del primer análisis y crear la copia para trabajar con los datos

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../data/processed/train.csv')

# %%
df = data.copy()

# %%
df.head(5)
# Out:
#    laptop_ID Company             Product     TypeName  Inches  Resolution_X  \
# 0       1223    Dell       Inspiron 5567     Notebook    15.6          1920
# 1         78  Lenovo  IdeaPad 320-15IKBN     Notebook    15.6          1920
# 2       1267    Dell              XPS 13  Convertible    13.3          3200
# 3        161    Dell       Inspiron 5579  Convertible    15.6          1920
# 4        922      LG         Gram 14Z970    Ultrabook    14.0          1920
#
#    Resolution_Y cat_resolution  Is_touch CPU_Brand      CPU_Model    SSD  \
# 0          1080        Full HD         0     Intel  Core i5 7200U  256.0
# 1          1080        Full HD         0     Intel  Core i5 7200U    0.0
# 2          1800            QHD         1     Intel   Core i5 7Y54  256.0
# 3          1080        Full HD         1     Intel  Core i7 8550U  256.0
# 4          1080        Full HD         1     Intel  Core i7 7500U  512.0
#
#     HDD  CPU_Frec  Ram GPU_Brand         GPU_Model  Is_GPU_dedicated  \
# 0     0       2.5  8.0       AMD    Radeon R7 M445                 1
# 1  2048       2.5  8.0     Intel   HD Graphics 620                 0
# 2     0       1.2  8.0     Intel   HD Graphics 615                 0
# 3     0       1.8  8.0     Intel  UHD Graphics 620                 0
# 4     0       2.7  8.0     Intel   HD Graphics 620                 0
#
#        OpSys  Weight  Price_euros
# 0    Windows    2.36        889.0
# 1  Chrome OS    2.20        519.0
# 2    Windows    1.24       1813.0
# 3    Windows    1.56       1049.0
# 4    Windows    0.98       1899.0

# %% [markdown]
# # Análisis exploratório de datos (EDA)

# %% [markdown]
# ## Estadisticas descriptivas

# %% [markdown]
# Tabla resumen detallada

# %%
tabla_resumen = CompleteDescribeTable(df)
tabla_resumen.describe_complete()

# %%
df_resumen = tabla_resumen.get_describe_complete()

# %%
df_resumen
# Out:
#                  tipo de dato tipo de variable  cardinalidad abs  \
# variable
# laptop_ID               int64         numerica               909
# Company                object       categorica                19
# Product                object       categorica               474
# TypeName               object       categorica                 6
# Inches                float64         numerica                18
# Resolution_X            int64         numerica                13
# Resolution_Y            int64         numerica                10
# cat_resolution         object       categorica                 4
# Is_touch                int64         numerica                 2
# CPU_Brand              object       categorica                 2
# CPU_Model              object       categorica                79
# SSD                   float64         numerica                11
# HDD                     int64         numerica                 6
# CPU_Frec              float64         numerica                24
# Ram                   float64         numerica                 6
# GPU_Brand              object       categorica                 3
# GPU_Model              object       categorica                88
# Is_GPU_dedicated        int64         numerica                 2
# OpSys                  object       categorica                 4
# Weight                float64         numerica               155
# Price_euros           float64         numerica               574
#
#                   cardinalidad %  distribucion  % missing  % Outliers  \
# variable
# laptop_ID             100.000000  No Gaussiana        0.0        0.00
# Company                 2.090209          None        0.0         NaN
# Product                52.145215          None        0.0         NaN
# TypeName                0.660066          None        0.0         NaN
# Inches                  1.980198  No Gaussiana        0.0        3.52
# Resolution_X            1.430143  No Gaussiana        0.0        5.39
# Resolution_Y            1.100110  No Gaussiana        0.0        9.35
# cat_resolution          0.440044          None        0.0         NaN
# Is_touch                0.220022  No Gaussiana        0.0       14.63
# CPU_Brand               0.220022          None        0.0         NaN
# CPU_Model               8.690869          None        0.0         NaN
# SSD                     1.210121  No Gaussiana        0.0        0.00
# HDD                     0.660066  No Gaussiana        0.0        0.00
# CPU_Frec                2.640264  No Gaussiana        0.0        0.00
# Ram                     0.660066  No Gaussiana        0.0        0.00
# GPU_Brand               0.330033          None        0.0         NaN
# GPU_Model               9.680968          None        0.0         NaN
# Is_GPU_dedicated        0.220022  No Gaussiana        0.0        0.00
# OpSys                   0.440044          None        0.0         NaN
# Weight                 17.051705  No Gaussiana        0.0        2.86
# Price_euros            63.146315  No Gaussiana        0.0        0.00
#
#                             rango    moda  mediana        media  \
# variable
# laptop_ID               (1, 1320)     1.0   657.00   660.613861
# Company                      None     NaN      NaN          NaN
# Product                      None     NaN      NaN          NaN
# TypeName                     None     NaN      NaN          NaN
# Inches               (10.1, 18.4)    15.6    15.60    14.951155
# Resolution_X         (1366, 3840)  1920.0  1920.00  1883.911991
# Resolution_Y          (768, 2160)  1080.0  1080.00  1065.091309
# cat_resolution               None     NaN      NaN          NaN
# Is_touch                   (0, 1)     0.0     0.00     0.146315
# CPU_Brand                    None     NaN      NaN          NaN
# CPU_Model                    None     NaN      NaN          NaN
# SSD                  (0.0, 640.0)   256.0   180.00   176.303630
# HDD                     (0, 2048)     0.0     0.00   403.823982
# CPU_Frec               (0.9, 3.6)     2.5     2.50     2.283718
# Ram                   (2.0, 14.0)     8.0     8.00     7.674367
# GPU_Brand                    None     NaN      NaN          NaN
# GPU_Model                    None     NaN      NaN          NaN
# Is_GPU_dedicated           (0, 1)     0.0     0.00     0.426843
# OpSys                        None     NaN      NaN          NaN
# Weight                (0.69, 4.7)     2.2     2.03     2.009058
# Price_euros       (191.9, 2787.0)  2787.0   949.00  1086.940308
#
#                   desv estandar      Q1      Q3  asimetria  curtosis  \
# variable
# laptop_ID            383.006455   326.0   995.0  -0.000727 -1.203360
# Company                     NaN     NaN     NaN        NaN       NaN
# Product                     NaN     NaN     NaN        NaN       NaN
# TypeName                    NaN     NaN     NaN        NaN       NaN
# Inches                 1.426708    14.0    15.6  -0.469307 -0.034489
# Resolution_X         491.125096  1440.0  1920.0   2.181619  6.510931
# Resolution_Y         282.733552   900.0  1080.0   2.088538  5.759030
# cat_resolution              NaN     NaN     NaN        NaN       NaN
# Is_touch               0.353616     0.0     0.0   2.004804  2.023686
# CPU_Brand                   NaN     NaN     NaN        NaN       NaN
# CPU_Model                   NaN     NaN     NaN        NaN       NaN
# SSD                  171.366406     0.0   256.0   0.701385 -0.256295
# HDD                  519.534157     0.0  1024.0   0.967599  0.136509
# CPU_Frec               0.522153     1.8     2.7  -0.796412 -0.273834
# Ram                    3.399860     4.0     8.0   0.606108 -0.457424
# GPU_Brand                   NaN     NaN     NaN        NaN       NaN
# GPU_Model                   NaN     NaN     NaN        NaN       NaN
# Is_GPU_dedicated       0.494891     0.0     1.0   0.296302 -1.916427
# OpSys                       NaN     NaN     NaN        NaN       NaN
# Weight                 0.644164     1.5     2.3   1.175398  2.988322
# Price_euros          639.474963   572.0  1458.0   0.896370  0.132960
#
#                   Valor estad.    Valor de P prueba normalidad tipo asimetria
# variable
# laptop_ID             0.953895  2.781331e-16         No normal       positiva
# Company                    NaN           NaN              None           None
# Product                    NaN           NaN              None           None
# TypeName                   NaN           NaN              None           None
# Inches                0.876010  2.860920e-26         No normal       negativa
# Resolution_X          0.649796  1.645085e-39         No normal       negativa
# Resolution_Y          0.661421  4.911096e-39         No normal       negativa
# cat_resolution             NaN           NaN              None           None
# Is_touch              0.420860  6.074332e-47         No normal       negativa
# CPU_Brand                  NaN           NaN              None           None
# CPU_Model                  NaN           NaN              None           None
# SSD                   0.824295  2.121300e-30         No normal       negativa
# HDD                   0.714255  1.078917e-36         No normal       negativa
# CPU_Frec              0.890976  7.941137e-25         No normal       negativa
# Ram                   0.821595  1.376133e-30         No normal       negativa
# GPU_Brand                  NaN           NaN              None           None
# GPU_Model                  NaN           NaN              None           None
# Is_GPU_dedicated      0.628756  2.444529e-40         No normal       negativa
# OpSys                      NaN           NaN              None           None
# Weight                0.916906  6.388109e-22         No normal       negativa
# Price_euros           0.921830  2.705791e-21         No normal       negativa

# %% [markdown]
# ## Análisis univariado

# %%
categoric_cols = df.select_dtypes(include='object').columns

# %%
plt.figure(figsize=(15,30))
for i, col in enumerate(categoric_cols):
    top_10 = df[col].value_counts().head(10)
    df_filtrado_top_10 = df[df[col].isin(top_10.index)]
    plt.subplot(6,2, i+1)
    sns.countplot(data=df_filtrado_top_10[col])
    plt.title(f'Histograma de {col}')
    plt.tight_layout()

# %% [markdown]
# Número de ocurrencias de las variables categóricas que reflejan cuales son los dominantes en cada una de ellas.
# * Columna Company
#     * La marca Dell domina el mercado, seguida de Lenovo, HP, Asus y Acer.
# * Columna Product
#     * Los modelos XPS 13 de Dell son los más comunes: XPS 13 (Dell), Inspiron 3567 (Dell), Vostro 3568 (Dell), 250 G6 (HP) y Inspiron 5570 (Dell). En los top 5 sólo una vez entra otra marca, la HP, lo que puede confirmar los datos dichos arriba.
# * Columna TypeName
#     * Los portátiles de uso general son los más comunes, seguidos por modelos gaming y ultrabook, que presentan una distribución similar.
# * Columna CPU_Brand
#     * Intel domina el mercado de procesadores seguido por AMD.
# * Columna CPU_Model
#     * El procesador Intel Core i5 7200U es el más utilizado, seguido de cerca por el Core i7 7700HQ y el Core i7 7500U.
# * Columna GPU_Brand
#     * Intel, Nvidia y AMD son las principales marcas de GPU, con Intel siendo la más dominante.
# * Columna GPU_Model
#     * La GPU Intel HD Graphics 620 es la más utilizada, seguida de la HD Graphics 520 y la GeForce GTX 1050.
# * Columna OpSys
#     * Windows es el sistema operativo más popular, seguido por Chrome OS, Linux y macOS.

# %%
plt.figure(figsize=(15,15))
for i, feature in enumerate(data.select_dtypes(include='number').columns):
    plt.subplot(12, 2 , i+1)
    sns.boxplot(x=data[feature], color='green' )
    plt.title(f'Boxplot de {feature}')

plt.tight_layout()
plt.show()

# %%
data[data['Price_euros'] > 4000]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, Resolution_X, Resolution_Y, cat_resolution, Is_touch, CPU_Brand, CPU_Model, SSD, HDD, CPU_Frec, Ram, GPU_Brand, GPU_Model, Is_GPU_dedicated, OpSys, Weight, Price_euros]
# Index: []

# %% [markdown]
# ## Tratamiento outliers

# %% [markdown]
# ### SSD

# %%
Q3 = df_resumen['Q3']['SSD']
Q1 = df_resumen['Q1']['SSD']

IQR = Q3 - Q1

limite_superior_SSD = Q3 + 1.5 * IQR
limite_inferior_SSD = Q1 - 1.5 * IQR

# %%
data['SSD'] = np.where(data['SSD'] > limite_superior_SSD, limite_superior_SSD, data['SSD'])

# %% [markdown]
# ### RAM

# %%
Q3 = df_resumen['Q3']['Ram']
Q1 = df_resumen['Q1']['Ram']

IQR = Q3 - Q1

limite_superior_RAM = Q3 + 1.5 * IQR
limite_inferior_RAM = Q1 - 1.5 * IQR

# %%
data['Ram'] = np.where(data['Ram'] > limite_superior_RAM, limite_superior_RAM, data['Ram'])

# %% [markdown]
# ### Price_euros

# %%
data = data[data['Price_euros'] < 4000]

# %%
Q3 = df_resumen['Q3']['Price_euros']
Q1 = df_resumen['Q1']['Price_euros']

IQR = Q3 - Q1

limite_superior_Price_euros = Q3 + 1.5 * IQR
limite_inferior_Price_euros = Q1 - 1.5 * IQR

# %%
data['Price_euros'] = np.where(data['Price_euros'] > limite_superior_Price_euros, limite_superior_Price_euros, data['Price_euros'])

# %%
limite_superior_Price_euros
# Out:
# np.float64(2787.0)

# %%
data['Price_euros'].max()
# Out:
# np.float64(2787.0)

# %%
plt.figure(figsize=(15,5))
for i, feature in enumerate(data.select_dtypes(include='number').columns):
    if feature in 'SSD' 'Ram' 'Price_euros':
        plt.subplot(13, 1 , i+1)
        sns.boxplot(x=data[feature], color='green' )
        plt.title(f'Boxplot de {feature}')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_19356\693144976.py:8: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df_encoded = df.copy()
categorical_cols = df_encoded.select_dtypes(include=['object']).columns

for col in categorical_cols:
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

correlation_matrix = df_encoded.corr()

filtered_correlatd_matrix = np.where((correlation_matrix >= .5) | (correlation_matrix <= -.5), correlation_matrix,0)

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Heatmap completo")
plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(filtered_correlatd_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Heatmap completo")
plt.show()

# %% [markdown]
# El gráfico de correlaciones revela una relación directa entre el precio de los equipos y ciertas especificaciones técnicas. Destaca una correlación positiva muy fuerte entre el precio y la memoria RAM, lo que indica que a medida que aumenta la cantidad de RAM, también lo hace el precio. Esta relación es lógica, ya que una mayor cantidad de RAM permite ejecutar más programas simultáneamente y realizar tareas más exigentes, lo cual es una característica muy valorada por los usuarios.
#
# Además de la memoria RAM, el tamaño del disco duro SSD también muestra una fuerte correlación positiva con el precio, lo que sugiere que los equipos con mayor capacidad de almacenamiento suelen ser más costosos. Asimismo, se observa una relación positiva entre el precio y la resolución de pantalla, así como con la frecuencia del procesador. Esto se debe a que pantallas de mayor resolución y procesadores más rápidos ofrecen un mejor rendimiento y una experiencia de usuario más satisfactoria.
#
# En resumen, las especificaciones que más influyen en el precio de un equipo son la memoria RAM, el tamaño del disco duro SSD, la resolución de pantalla y la frecuencia del procesador. Estas características son consideradas por los fabricantes como un valor agregado y, por lo tanto, se reflejan en un precio más elevado.

# %%
data.to_csv('../data/processed/test.csv', index=False)
